# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 52.7 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=42cc71e7f51670c192f9aec142f790a751bde3ee3bf0d2b6fcbc2eaeed1f35e8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport # updated import statement

# %%
import pandas as pd
df = pd.read_csv('./sample_data/dog_breeds.csv')
df.head()
# Out:
#                  Name  min_life_expectancy  max_life_expectancy  \
# 0    Golden Retriever                   10                   12
# 1           Dachshund                   12                   16
# 2  Labrador Retriever                   10                   12
# 3          Great Dane                    7                   10
# 4               Boxer                   10                   12
#
#    max_height_male  max_height_female  max_weight_male  max_weight_female  \
# 0             24.0               24.0             75.0               65.0
# 1              9.0                9.0             32.0               32.0
# 2             24.5               24.5             80.0               70.0
# 3             32.0               32.0            175.0              140.0
# 4             25.0               25.0             80.0               65.0
#
#    min_height_male  min_height_female  min_weight_male  ...  shedding  \
# ...

# %%
from matplotlib import pyplot as plt
_df_33['max_height_male'].plot(kind='line', figsize=(8, 4), title='max_height_male')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_25.plot(kind='scatter', x='max_height_male', y='max_height_female', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_31['min_life_expectancy'].plot(kind='line', figsize=(8, 4), title='min_life_expectancy')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_18['min_life_expectancy'].plot(kind='hist', bins=20, title='min_life_expectancy')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_21.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_17['index'].plot(kind='hist', bins=20, title='index')
plt.gca().spines[['top', 'right',]].set_visible(False)
