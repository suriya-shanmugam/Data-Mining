# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-598d0993-829b-4d39-a297-23dde5c537ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-598d0993-829b-4d39-a297-23dde5c537ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir commodity_data_set
# !cp Date-Wise-Prices-all-Commodity.xlsx  commodity_data_set/

# %%
directory = '/content/commodity_data_set/'

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_excel(directory+'Date-Wise-Prices-all-Commodity.xlsx')

# %%
train_data.head()
# Out:
#   diffgr:id  msdata:rowOrder           State District      Market  \
# 0    Table1                0  Andhra Pradesh  Chittor    Chittoor
# 1    Table2                1  Andhra Pradesh  Chittor    Chittoor
# 2    Table3                2  Andhra Pradesh  Chittor    Chittoor
# 3    Table4                3  Andhra Pradesh  Chittor    Punganur
# 4    Table5                4  Andhra Pradesh  Chittor  Vayalapadu
#
#       Commodity Variety Grade Arrival_Date  Min_x0020_Price  Max_x0020_Price  \
# 0  Gur(Jaggery)    NO 1   FAQ   24/02/2023             4000           4100.0
# 1  Gur(Jaggery)    NO 2   FAQ   24/02/2023             3000           3500.0
# 2  Gur(Jaggery)    NO 3   FAQ   24/02/2023             2300           2300.0
# 3        Tomato  Hybrid   FAQ   24/02/2023             1340           2000.0
# 4        Tomato   Local   FAQ   24/02/2023              640           2160.0
#
#    Modal_x0020_Price
# 0             4000.0
# 1             3500.0
# 2             2300.0
# ...

# %%
from pycaret.regression import *
s = setup(train_data, target = 'Modal_x0020_Price', session_id = 123)
# Out:
# <style type="text/css">
# #T_34120_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_34120" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34120_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_34120_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34120_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34120_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_34120_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_34120_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34120_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_34120_row1_col1" class="data row1 col1" >Modal_x0020_Price</td>
#     </tr>
#     <tr>
#       <th id="T_34120_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# compare baseline models
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_a4977 th {
#   text-align: left;
# }
# ...

# %%
huber_model = create_model('huber')
# Out:
# <style type="text/css">
# #T_305d4_row10_col0, #T_305d4_row10_col1, #T_305d4_row10_col2, #T_305d4_row10_col3, #T_305d4_row10_col4, #T_305d4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_305d4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_305d4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_305d4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_305d4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_305d4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_305d4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_305d4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# !pip install pycaret[mlops]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 72.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 92.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 22.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 19.5 MB/s eta 0:00:00
# ...

# %%
create_app(huber_model)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://86ab4772919648161b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://86ab4772919648161b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
